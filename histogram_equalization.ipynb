# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline


def find_hist_of_img(img):
    img_hist = np.zeros((256,))
    img_size =img.shape[0]*img.shape[1]
    for i in img.flatten():
        img_hist[i] += 1
    return img_hist

image = cv2.imread("cat_with_mask.jpeg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

plt.imshow(image)


#for i in range(256):
#    img_hist[i] = np.count_nonzero(image==i)

# %%
img_hist = find_hist_of_img(image)
plt.plot(img_hist)

# %%
hist_sum = np.cumsum(img_hist)
plt.plot(hist_sum)
n = (hist_sum*255/image_size).astype('int')
plt.plot(n)

# %%
hist_image = image.copy()
for i in range(256):
    hist_image[image==i] = n[i]
plt.imshow(hist_image)

# %%
plt.plot(find_hist_of_img(hist_image))

# %%
# Out:
# [1 2]
# [1 2 3 4]

# %%
# Out:
# [[254 254 254 ... 254 254 254]
#  [254 254 254 ... 254 254 254]
#  [254 254 254 ... 254 254 254]
#  ...
#  [  3   3   3 ... 254 254 254]
#  [  3   3   3 ... 254 254 254]
#  [  3   3   3 ... 254 254 254]]
